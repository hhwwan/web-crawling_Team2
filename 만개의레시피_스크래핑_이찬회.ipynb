# %% [markdown]
# ## 모든 레시피의 ID값을 리스트로 반환

# %%
import requests
from bs4 import BeautifulSoup
import time

def get_all_recipe_links():
    """
    '만개의 레시피' 사이트에서 전체 항목의 모든 페이지를 크롤링하여 'common_sp_link' 클래스의 href 속성 중 레시피 ID만 반환.

    Returns:
        list: 모든 페이지의 레시피 ID 값 리스트
    """

    base_url = "https://www.10000recipe.com/recipe/list.html"
    recipe_ids = []

    try:
        for page in range(1, 10000):
            if page % 100 == 0:
                print(f"Crawling page {page}...")

            page_url = f"{base_url}?order=reco&page={page}"
            for _ in range(3):  # 최대 3번 재시도
                try:
                    response = requests.get(page_url)
                    response.raise_for_status()
                    break  # 요청 성공 시 루프 종료
                except requests.RequestException as e:
                    print(f"Retrying page {page} due to error: {e}")
                    time.sleep(2)  # 재시도 간 딜레이
            else:
                print(f"Skipping page {page} after multiple failures.")
                continue

            soup = BeautifulSoup(response.text, 'html.parser')
            links = soup.find_all('a', class_='common_sp_link')
            ids = [link['href'].split('/')[-1] for link in links if 'href' in link.attrs]

            if not ids:
                print(f"No links found on page {page}. Stopping search.")
                break

            recipe_ids.extend(ids)
            time.sleep(0.2)  # 요청 간 딜레이

        return recipe_ids
    except Exception as e:
        print(f"Error during scraping: {e}")
        return []

result_ids = get_all_recipe_links()
print(len(result_ids))
print(result_ids)
# Out:
# Crawling page 100...
# Retrying page 133 due to error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Crawling page 200...
# Crawling page 300...
# Crawling page 400...
# Crawling page 500...
# Crawling page 600...
# Crawling page 700...
# Retrying page 751 due to error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Crawling page 800...
# Crawling page 900...
# Crawling page 1000...
# Crawling page 1100...
# Crawling page 1200...
# Crawling page 1300...
# Crawling page 1400...
# Crawling page 1500...
# Crawling page 1600...
# Crawling page 1700...
# Crawling page 1800...
# Crawling page 1900...
# Crawling page 2000...
# Crawling page 2100...
# Crawling page 2200...
# Crawling page 2300...
# Crawling page 2400...
# Crawling page 2500...
# Crawling page 2600...
# Crawling page 2700...
# Crawling page 2800...
# Crawling page 2900...
# Crawling page 3000...
# Crawling page 3100...
# Retrying page 3127 due to error: HTTPSConnectionPool(host='www.10000recipe.com', port=443): Max retries exceeded with url: /recipe/list.html?order=reco&page=3127 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Crawling page 3200...
# Crawling page 3300...
# Crawling page 3400...
# Crawling page 3500...
# Crawling page 3600...
# Crawling page 3700...
# Retrying page 3753 due to error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Crawling page 3800...
# Crawling page 3900...
# Crawling page 4000...
# Crawling page 4100...
# Crawling page 4200...
# Crawling page 4300...
# Retrying page 4399 due to error: HTTPSConnectionPool(host='www.10000recipe.com', port=443): Max retries exceeded with url: /recipe/list.html?order=reco&page=4399 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Crawling page 4400...
# Crawling page 4500...
# Crawling page 4600...
# Crawling page 4700...
# Crawling page 4800...
# Crawling page 4900...
# Crawling page 5000...
# Crawling page 5100...
# Crawling page 5200...
# Crawling page 5300...
# Crawling page 5400...
# Crawling page 5500...
# Crawling page 5600...
# Crawling page 5700...
# Crawling page 5800...
# No links found on page 5862. Stopping search.
# 234408
# ['7039214', '6984517', '7009944', '7003487', '7029407', '7022775', '6989690', '7007585', '7023640', '6993517', '7035725', '7033948', '7025833', '7017809', '7005830', '7035751', '7028655', '7038084', '7030095', '6991123', '6992063', '7013562', '7006926', '7014608', '7004418', '7029194', '7004229', '6984423', '6957003', '7007197', '7017649', '7030132', '7006705', '6933414', '7033609', '7032079', '7001752', '7020127', '6994258', '6912734', '6983042', '7035279', '7020587', '7011840', '7004960', '6981985', '7002329', '7035901', '6995956', '6997077', '6933760', '7018922', '6992944', '7003451', '7029097', '7011685', '6957535', '4030952', '6843136', '7036904', '7018178', '7025424', '6915088', '7023485', '7009241', '7027008', '6978378', '6907091', '7024640', '7006608', '7026723', '7015517', '7007710', '6840157', '7002422', '6951564', '6830616', '7028113', '6983882', '6897383', '7030722', '7022766', '7004853', '6989041', '7038405', '7037106', '6962486', '6952025', '6877253', '6913952', '6975337', '6875304', '6918934', '7010409', '6885909', '6996297', '7014484', '6897374', '6846168', '7016910', '7002427', '6894755', '6966445', '2399193', '6991245', '7037835', '6891606', '6990828', '6892209', '6924130', '6869489', '6881099', '6869017', '6910706', '6959420', '6918383', '6895591', '7020548', '6969794', '7028555', '6946282', '6980995', '6881815', '6939980', '6834258', '6868389', '7031635', '6994439', '6922700', '1802633', '6894323', '6965981', '7011422', '7037956', '6930302', '6988709', '6948513', '6969724', '6916408', '6885805', '6886357', '7004934', '6998777', '6912739', '6922190', '6955413', '6847470', '6956954', '7002301', '6899265', '6871953', '6952286', '6898497', '6988775', '6930961', '6984643', '6887226', '6863696', '7013057', '6932918', '7027794', '6886034', '6878340', '6919305', '6853446', '7014762', '6918977', '7001408', '7039230', '6892728', '6920393', '7036196', '6901939', '6884169', '6925564', '6881806', '6866122', '6854893', '6980900', '6875055', '6954484', '6867650', '6932924', '7010976', '6980888', '6854230', '6831048', '6876875', '6892442', '6847506', '6952146', '6983253', '7004080', '7021205', '6953539', '6943349', '6939082', '7037900', '6933349', '6854799', '6874866', '6910228', '6890777', '6883649', '6909570', '6868435', '6850385', '6956266', '6977567', '6872474', '6852019', '7014721', '7003388', '6842456', '7031316', '6929388', '6898369', '6900601', '7013219', '6874797', '6913489', '6968567', '6892715', '6904344', '6886281', '6912539', '6886567', '6994661', '6897704', '7006126', '6831990', '6867358', '6842114', '6916655', '6887603', '6847884', '6891556', '6910384', '6860385', '7003814', '6935331', '6862339', '7027944', '7017097', '6844877', '7020260', '6854979', '6860598', '6828951', '6836906', '7016404', '6867736', '6880679', '6989529', '6989786', '7007929', '7032267', '6867306', '6835071', '6922734', '7035205', '6868392', '6891823', '6841156', '6879543', '7009401', '6865340', '6857631', '6839363', '7021091', '7008869', '6874871', '6998798', '6895266', '4197710', '6985504', '6832044', '6882435', '6918300', '6924357', '6843348', '6739157', '6978052', '7029684', '6949579', '7017631', '6907712', '6875696', '6913806', '6837731', '7035098', '6857754', '6899340', '6855421', '6893218', '6841290', '6902300', '7004654', '6907784', '6904793', '7030325', '6953644', '6904080', '6904643', '6992061', '6871815', '6829153', '7002443', '6835355', '6899367', '6844208', '6952367', '6927971', '6922742', '6914310', '6894872', '6920397', '6894538', '7038475', '7005355', '6831876', '6880341', '7001546', '6928511', '1135209', '4145941', '7036134', '7018228', '7022304', '6811239', '6922432', '6910980', '6890570', '6909721', '6911766', '6930572', '6904864', '6984865', '6831988', '6842280', '6975041', '6887551', '6882848', '6902441', '7039115', '6842110', '7014837', '4803252', '7035762', '6863792', '6994106', '6885808', '6948579', '6965550', '6861562', '6977898', '7020842', '6858529', '6925795', '5269045', '6905276', '6917038', '6965877', '68532 ...

# %% [markdown]
# ## 얻은 레시피 ID 값들을 파일로 저장

# %%
import csv

# CSV 파일로 저장
with open('recipe_id.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    for recipe_id in result_ids:
        writer.writerow([recipe_id])

print("Result IDs have been saved to result_ids.csv")
# Out:
# Result IDs have been saved to result_ids.csv

# %% [markdown]
# ## 레시피 정보, 레시피 재료, 레시피 조리도구 테이블 생성
#
# **레시피 정보 데이터프레임**
#
# recipe_id, recipe_name, summary, amount, cooking_time, difficulty_level
#
# <br>
#
# **레시피 재료 데이터프레임**
#
# recipe_id, ingredient_name, ingredient_amount
#
# <br>
#
# **레시피 조리도구 데이터프레임**
#
# recipe_id, utensil

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def fetch_recipe_page(recipe_id, max_retries=3):
    """
    주어진 레시피 ID에 해당하는 페이지를 요청하고 BeautifulSoup 객체를 반환.
    요청 간 0.2초 텀을 주며, 오류 발생 시 최대 3번까지 재시도.

    Parameters:
        recipe_id (str): 레시피 ID
        max_retries (int): 최대 재시도 횟수 (기본값 3)

    Returns:
        BeautifulSoup: 파싱된 HTML 페이지
    """
    base_url = "https://www.10000recipe.com/recipe/"
    url = f"{base_url}{recipe_id}"

    for attempt in range(max_retries):
        try:
            response = requests.get(url)
            response.raise_for_status()
            time.sleep(0.2)  # 요청 간 0.2초 텀 추가
            return BeautifulSoup(response.text, 'html.parser')
        except requests.RequestException as e:
            print(f"Error fetching recipe {recipe_id} (Attempt {attempt + 1}): {e}")
            time.sleep(0.2)  # 재시도 전에도 0.2초 텀 추가
    print(f"Failed to fetch recipe {recipe_id} after {max_retries} attempts.")
    return None

def parse_recipe_info(soup, recipe_id):
    """
    레시피 정보를 추출하여 딕셔너리로 반환.

    Parameters:
        soup (BeautifulSoup): 파싱된 HTML 페이지
        recipe_id (str): 레시피 ID

    Returns:
        dict: 레시피 정보
    """
    if soup is None:
        return None

    recipe_name = soup.find('h3').get_text(strip=True) if soup.find('h3') else "N/A"
    summary = soup.find('div', id='recipeIntro').get_text(strip=True) if soup.find('div', id='recipeIntro') else "N/A"
    amount = soup.find('span', class_='view2_summary_info1').get_text(strip=True) if soup.find('span', class_='view2_summary_info1') else "N/A"
    cooking_time = soup.find('span', class_='view2_summary_info2').get_text(strip=True) if soup.find('span', class_='view2_summary_info2') else "N/A"
    difficulty_level = soup.find('span', class_='view2_summary_info3').get_text(strip=True) if soup.find('span', class_='view2_summary_info3') else "N/A"

    return {
        "recipe_id": recipe_id,
        "recipe_name": recipe_name,
        "summary": summary,
        "amount": amount,
        "cooking_time": cooking_time,
        "difficulty_level": difficulty_level
    }

def parse_ingredients(soup, recipe_id):
    """
    재료 정보를 추출하여 리스트로 반환.

    Parameters:
        soup (BeautifulSoup): 파싱된 HTML 페이지
        recipe_id (str): 레시피 ID

    Returns:
        list: 재료 정보 딕셔너리의 리스트
    """
    if soup is None:
        return []

    ingredient_data = []
    ingredient_section = soup.find('div', id='divConfirmedMaterialArea')
    if ingredient_section:
        ingredients = ingredient_section.find_all('div', class_='ingre_list_name')
        ingredient_amounts = ingredient_section.find_all('span', class_='ingre_list_ea')

        for ingre, amount in zip(ingredients, ingredient_amounts):
            ingredient_data.append({
                "recipe_id": recipe_id,
                "ingredient_name": ingre.get_text(strip=True),
                "ingredient_amount": amount.get_text(strip=True)
            })
    return ingredient_data

def parse_utensils(soup, recipe_id):
    """
    조리도구 정보를 추출하여 리스트로 반환.

    Parameters:
        soup (BeautifulSoup): 파싱된 HTML 페이지
        recipe_id (str): 레시피 ID

    Returns:
        list: 조리도구 정보 딕셔너리의 리스트
    """
    if soup is None:
        return []

    utensil_data = []
    all_items = soup.find_all('div', class_='ingre_list_name')
    for item in all_items:
        # 상위 노드가 id="divConfirmedMaterialArea"가 아닌 경우만 조리도구로 간주
        if not item.find_parent('div', id='divConfirmedMaterialArea'):
            utensil_data.append({
                "recipe_id": recipe_id,
                "utensil": item.get_text(strip=True)
            })
    return utensil_data

def scrape_recipe_details_and_ingredients(recipe_ids):
    """
    주어진 레시피 ID 리스트를 사용하여 각 레시피의 상세 정보, 재료 정보, 조리도구 정보를 데이터프레임으로 반환.
    100번째 반복마다 데이터를 CSV 파일로 저장.

    Parameters:
        recipe_ids (list): 레시피 ID 리스트

    Returns:
        tuple: (레시피 정보 데이터프레임, 재료 정보 데이터프레임, 조리도구 정보 데이터프레임)
    """
    recipe_data = []
    ingredient_data = []
    utensil_data = []

    for id, recipe_id in enumerate(recipe_ids):
        if id % 100 == 0 and id > 0:
            print(f"Processing recipe {id}/{len(recipe_ids)}...")

            # 100번째 반복마다 데이터를 임시로 CSV 파일로 저장 (utf-8-sig 인코딩)
            recipe_df = pd.DataFrame(recipe_data)
            ingredient_df = pd.DataFrame(ingredient_data)
            utensil_df = pd.DataFrame(utensil_data)

            recipe_df.to_csv(f"recipe_data_partial.csv", index=False, encoding='utf-8-sig')
            ingredient_df.to_csv(f"ingredient_data_partial.csv", index=False, encoding='utf-8-sig')
            utensil_df.to_csv(f"utensil_data_partial.csv", index=False, encoding='utf-8-sig')
            print(f"Saved intermediate data at iteration {id}.")

        soup = fetch_recipe_page(recipe_id)

        # 레시피 정보 추가
        recipe_info = parse_recipe_info(soup, recipe_id)
        if recipe_info:
            recipe_data.append(recipe_info)

        # 재료 정보 추가
        ingredient_data.extend(parse_ingredients(soup, recipe_id))

        # 조리도구 정보 추가
        utensil_data.extend(parse_utensils(soup, recipe_id))

    # 최종 데이터프레임 생성
    recipe_df = pd.DataFrame(recipe_data)
    ingredient_df = pd.DataFrame(ingredient_data)
    utensil_df = pd.DataFrame(utensil_data)

    # 최종 데이터 저장 (utf-8-sig 인코딩)
    recipe_df.to_csv("recipe_data_final.csv", index=False, encoding='utf-8-sig')
    ingredient_df.to_csv("ingredient_data_final.csv", index=False, encoding='utf-8-sig')
    utensil_df.to_csv("utensil_data_final.csv", index=False, encoding='utf-8-sig')
    print("Saved final data to CSV.")

    return recipe_df, ingredient_df, utensil_df



# 함수 사용 예제
recipe_ids = result_ids[:10000]
recipe_df, ingredient_df, utensil_df = scrape_recipe_details_and_ingredients(recipe_ids)

# 출력 결과 확인
print("Recipe DataFrame:")
print(recipe_df)
print("\nIngredient DataFrame:")
print(ingredient_df)
print("\nUtensil DataFrame:")
print(utensil_df)
# Out:
# Processing recipe 100/10000...
# Saved intermediate data at iteration 100.
# Processing recipe 200/10000...
# Saved intermediate data at iteration 200.
# Processing recipe 300/10000...
# Saved intermediate data at iteration 300.
# Processing recipe 400/10000...
# Saved intermediate data at iteration 400.
# Processing recipe 500/10000...
# Saved intermediate data at iteration 500.
# Processing recipe 600/10000...
# Saved intermediate data at iteration 600.
# Error fetching recipe 6949975 (Attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing recipe 700/10000...
# Saved intermediate data at iteration 700.
# Processing recipe 800/10000...
# Saved intermediate data at iteration 800.
# Processing recipe 900/10000...
# Saved intermediate data at iteration 900.
# Processing recipe 1000/10000...
# Saved intermediate data at iteration 1000.
# Processing recipe 1100/10000...
# Saved intermediate data at iteration 1100.
# Processing recipe 1200/10000...
# Saved intermediate data at iteration 1200.
# Error fetching recipe 6922355 (Attempt 1): HTTPSConnectionPool(host='www.10000recipe.com', port=443): Max retries exceeded with url: /recipe/6922355 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Processing recipe 1300/10000...
# Saved intermediate data at iteration 1300.
# Processing recipe 1400/10000...
# Saved intermediate data at iteration 1400.
# Processing recipe 1500/10000...
# Saved intermediate data at iteration 1500.
# Processing recipe 1600/10000...
# Saved intermediate data at iteration 1600.
# Error fetching recipe 6869163 (Attempt 1): ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Processing recipe 1700/10000...
# Saved intermediate data at iteration 1700.
# Processing recipe 1800/10000...
# Saved intermediate data at iteration 1800.
# Processing recipe 1900/10000...
# Saved intermediate data at iteration 1900.
# Processing recipe 2000/10000...
# Saved intermediate data at iteration 2000.
# Processing recipe 2100/10000...
# Saved intermediate data at iteration 2100.
# Processing recipe 2200/10000...
# Saved intermediate data at iteration 2200.
# Processing recipe 2300/10000...
# Saved intermediate data at iteration 2300.
# Processing recipe 2400/10000...
# Saved intermediate data at iteration 2400.
# Processing recipe 2500/10000...
# Saved intermediate data at iteration 2500.
# Error fetching recipe 6838708 (Attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error fetching recipe 3927413 (Attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error fetching recipe 6881229 (Attempt 1): HTTPSConnectionPool(host='www.10000recipe.com', port=443): Max retries exceeded with url: /recipe/6881229 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Processing recipe 2600/10000...
# Saved intermediate data at iteration 2600.
# Processing recipe 2700/10000...
# Saved intermediate data at iteration 2700.
# Processing recipe 2800/10000...
# Saved intermediate data at iteration 2800.
# Processing recipe 2900/10000...
# Saved intermediate data at iteration 2900.
# Processing recipe 3000/10000...
# Saved intermediate data at iteration 3000.
# Processing recipe 3100/10000...
# Saved intermediate data at iteration 3100.
# Processing recipe 3200/10000...
# Saved intermediate data at iteration 3200.
# Processing recipe 3300/10000...
# Saved intermediate data at iteration 3300.
# Processing recipe 3400/10000...
# Saved intermediate data at iteration 3400.
# Processing recipe 3500/10000...
# Saved intermediate data at iteration 3500.
# Error fetching recipe 6920226 (Attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing recipe 3600/10000...
# Saved intermediate data at iteration 3600.
# Processing recipe 3700/10000...
# Saved intermediate data at iteration 3700.
# Processing recipe 3800/10000...
# Saved intermediate data at iteration 3800.
# Processing recipe 3900/10000...
# Saved intermediate data at iteration 3900.
# Processing recipe 4000/10000...
# Saved intermediate data at iteration 4000.
# Processing recipe 4100/10000...
# Saved intermediate data at iteration 4100.
# Processing recipe 4200/10000...
# Saved intermediate data at iteration 4200.
# Error fetching recipe 6878864 (Attempt 1): HTTPSConnectionPool(host='www.10000recipe.com', port=443): Max retries exceeded with url: /recipe/6878864 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Processing recipe 4300/10000...
# Saved intermediate data at iteration 4300.
# Processing recipe 4400/10000...
# Saved intermediate data at iteration 4400.
# Processing recipe 4500/10000...
# Saved intermediate data at iteration 4500.
# Processing recipe 4600/10000...
# Saved intermediate data at iteration 4600.
# Processing recipe 4700/10000...
# Saved intermediate data at iteration 4700.
# Error fetching recipe 6923989 (Attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing recipe 4800/10000...
# Saved intermediate data at iteration 4800.
# Processing recipe 4900/10000...
# Saved intermediate data at iteration 4900.
# Error fetching recipe 6638953 (Attempt 1): HTTPSConnectionPool(host='www.10000recipe.com', port=443): Max retries exceeded with url: /recipe/6638953 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Processing recipe 5000/10000...
# Saved intermediate data at iteration 5000.
# Processing recipe 5100/10000...
# Saved intermediate data at iteration 5100.
# Error fetching recipe 6880778 (Attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing recipe 5200/10000...
# Saved intermediate data at iteration 5200.
# Processing recipe 5300/10000...
# Saved intermediate data at iteration 5300.
# Processing recipe 5400/10000...
# Saved intermediate data at iteration 5400.
# Processing recipe 5500/10000...
# Saved intermediate data at iteration 5500.
# Processing recipe 5600/10000...
# Saved intermediate data at iteration 5600.
# Processing recipe 5700/10000...
# Saved intermediate data at iteration 5700.
# Processing recipe 5800/10000...
# Saved intermediate data at iteration 5800.
# Processing recipe 5900/10000...
# Saved intermediate data at iteration 5900.
# Processing recipe 6000/10000...
# Saved intermediate data at iteration 6000.
# Processing recipe 6100/10000...
# Saved intermediate data at iteration 6100.
# Processing recipe 6200/10000...
# Saved intermediate data at iteration 6200.
# Error fetching recipe 4863521 (Attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing recipe 6300/10000...
# Saved intermediate data at iteration 6300.
# Processing recipe 6400/10000...
# Saved intermediate data at iteration 6400.
# Processing recipe 6500/10000...
# Saved intermediate data at iteration 6500.
# Processing recipe 6600/10000...
# Saved intermediate data at iteration 6600.
# Processing recipe 6700/10000...
# Saved intermediate data at iteration 6700.
# Processing recipe 6800/10000...
# Saved intermediate data at iteration 6800.
# Processing recipe 6900/10000...
# Saved intermediate data at iteration 6900.
# Processing recipe 7000/10000...
# Saved intermediate data at iteration 7000.
# Processing recipe 7100/10000...
# Saved intermediate data at iteration 7100.
# Error fetching recipe 6945261 (Attempt 1): HTTPSConnectionPool(host='www.10000recipe.com', port=443): Max retries exceeded with url: /recipe/6945261 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Processing recipe 7200/10000...
# Saved intermediate data at iteration 7200.
# Processing recipe 7300/10000...
# Saved intermediate data at iteration 7300.
# Processing recipe 7400/10000...
# Saved intermediate data at iteration 7400.
# Error fetching recipe 6914217 (Attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing recipe 7500/10000...
# Saved intermediate data at iteration 7500.
# Processing recipe 7600/10000...
# Saved intermediate data at iteration 7600.
# Processing recipe 7700/10000...
# Saved intermediate data at iteration 7700.
# Processing recipe 7800/10000...
# Saved intermediate data at iteration 7800.
# Processing recipe 7900/10000...
# Saved intermediate data at iteration 7900.
# Processing recipe 8000/10000...
# Saved intermediate data at iteration 8000.
# Processing recipe 8100/10000...
# Saved intermediate data at iteration 8100.
# Processing recipe 8200/10000...
# Saved intermediate data at iteration 8200.
# Processing recipe 8300/10000...
# Saved intermediate data at iteration 8300.
# Processing recipe 8400/10000...
# Saved intermediate data at iteration 8400.
# Error fetching recipe 6857611 (Attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing recipe 8500/10000...
# Saved intermediate data at iteration 8500.
# Processing recipe 8600/10000...
# Saved intermediate data at iteration 8600.
# Error fetching recipe 6958375 (Attempt 1): HTTPSConnectionPool(host='www.10000recipe.com', port=443): Max retries exceeded with url: /recipe/6958375 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Processing recipe 8700/10000...
# Saved intermediate data at iteration 8700.
# Error fetching recipe 6663134 (Attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing recipe 8800/10000...
# Saved intermediate data at iteration 8800.
# Processing recipe 8900/10000...
# Saved intermediate data at iteration 8900.
# Processing recipe 9000/10000...
# Saved intermediate data at iteration 9000.
# Processing recipe 9100/10000...
# Saved intermediate data at iteration 9100.
# Processing recipe 9200/10000...
# Saved intermediate data at iteration 9200.
# Processing recipe 9300/10000...
# Saved intermediate data at iteration 9300.
# Processing recipe 9400/10000...
# Saved intermediate data at iteration 9400.
# Processing recipe 9500/10000...
# Saved intermediate data at iteration 9500.
# Processing recipe 9600/10000...
# Saved intermediate data at iteration 9600.
# Processing recipe 9700/10000...
# Saved intermediate data at iteration 9700.
# Processing recipe 9800/10000...
# Saved intermediate data at iteration 9800.
# Processing recipe 9900/10000...
# Saved intermediate data at iteration 9900.
# Saved final data to CSV.
# Recipe DataFrame:
#      recipe_id                          recipe_name  \
# 0      7039214                     치킨너겟 교촌 허니콤보 만들기
# 1      6984517                 도시락 반찬으로 최고! 스팸감자조림♡
# 2      7009944  오이고추된장무침 (사계절 먹기좋은 밑반찬 고추무침 5분 레시피)
# 3      7003487                          청경채 된장 무침으로
# 4      7029407                   즉석,오이 부추 무침(백종원양념)
# ...        ...                                  ...
# 9995   6899153                               쪽파 겉절이
# 9996   6921313                     유아/아이들반찬 올방개묵무침!
# 9997   6952648                아삭한 식감 살리는 콩나물무침 아이반찬
# 9998   6985282              초간단 밥반찬\n미나리 겉절이 미나리 무침
# 9999   5980412                            오이뱃두리 만들기
#
#                                                 summary amount cooking_time  \
# 0     냉동치킨너겟으로 간편하게 만드는 교촌 허니콤보. 아이들간식은 물론 맥주안주로도 그만...    1인분       15분 이내
# 1                                           단짠단짠 맛있어요^^    2인분       10분 이내
# 2         오이고추로 만든 밥반찬 밑반찬입니다 불 없이 초간단하게 만들 수 있는 레시피입니다    4인분        5분 이내
# 3     청경채는 샤브샤브와 볶음으로만 만들었는데 샤브샤브 해먹고 남은 청경채를 초간단 된장...    3인분       20분 이내
# 4       냉장고에 오이 있으세요? 밥 반찬 없으시다면 후다닥~ 양념에 무쳐 맛나게 즐겨보세요.    2인분       20분 이내
# ...                                                 ...    ...          ...
# 9995  우리집은 익은 쪽파 김치 보다알싸한 매운맛만 가시면 바로 먹은 안익은 쪽파김치를 즐...    5인분       30분 이내
# 9996  청포묵이 아닌 올방개묵으로 묵무침을 해봤어요저자극/저염식으로 유아/아이들반찬 또는 ...    4인분       10분 이내
# 9997  식당가면 주는 반찬중에 아삭한 콩나물무침이 있잖아요~아삭한 식감 살리는 콩나물무침 ...    3인분       10분 이내
# 9998             간단하면서 데치지 않는 나물 무침을 만들고 싶어서 만든 미나리 겉절이    2인분        5분 이내
# 9999                      아작아작 씹는 소리도 맛있는 오이뱃두리 만들어볼게요~    3인분       60분 이내
#
#      difficulty_level
# 0                  초급
# 1                  초급
# 2                 아무나
# 3                 아무나
# 4                 아무나
# ...               ...
# 9995               초급
# 9996              아무나
# 9997              아무나
# 9998              아무나
# 9999               초급
#
# [10000 rows x 6 columns]
#
# Ingredient DataFrame:
#       recipe_id ingredient_name ingredient_amount
# 0       7039214      치킨너겟11개 이상               11개
# 1       7039214             진간장                1T
# 2       7039214              맛술                1T
# 3       7039214               물                1T
# 4       7039214            다진마늘              0.3T
# ...         ...             ...               ...
# 91797   5980412             다진파
# 91798   5980412              마늘                조금
# 91799   5980412              소금
# 91800   5980412              통깨
# 91801   5980412             참기름
#
# [91802 rows x 3 columns]
#
# Utensil DataFrame:
#      recipe_id utensil
# 0      7039214    프라이팬
# 1      7039214    요리집게
# 2      7039214     소스볼
# 3      7039214    계량스푼
# 4      7039214      접시
# ...        ...     ...
# 5259   7003690    프라이팬
# 5260   7003690    요리스푼
# 5261   7000016      도마
# 5262   7000016   조리용스푼
# 5263   7000016     믹싱볼
#
# [5264 rows x 2 columns]

# %% [markdown]
# 시간이 너무 오래 걸려 10000개의 레시피만 스크래핑하였습니다.
